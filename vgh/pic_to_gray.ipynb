# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2        #openCV2
from scipy import misc
import imageio
from PIL import Image
import random

# %matplotlib inline

# %%
# img=misc.imread("./pic/1511340541.vImage")
# plt.imshow(img)
# print img

im = Image.open("./pic/1511340541.vImage")
im = im.convert("L")
# plt.imshow(img, cmap='gray')
print im.format, im.size, im.mode
plt.imshow(np.asarray(im)/256.0, 'gray')
print np.asarray(im)/256.0
# Out:
# None (130, 50) L
# [[ 0.8203125   0.8203125   0.8203125  ...,  0.8203125   0.8203125
#    0.8203125 ]
#  [ 0.82421875  0.8203125   0.82421875 ...,  0.8203125   0.8203125
#    0.8203125 ]
#  [ 0.8203125   0.82421875  0.8203125  ...,  0.8203125   0.8203125
#    0.8203125 ]
#  ...,
#  [ 0.8203125   0.8203125   0.8203125  ...,  0.8203125   0.82421875
#    0.82421875]
#  [ 0.8203125   0.8203125   0.8203125  ...,  0.8203125   0.8203125
#    0.8203125 ]
#  [ 0.8203125   0.8203125   0.8203125  ...,  0.8203125   0.8203125
#    0.8203125 ]]

# %%
img=misc.imread("./pic/1511340541.vImage", 'L')
# 'L' => read and transfer to grayscale
plt.imshow(img, cmap='gray')
# cmap='gray' => plot grayscale
print img
# Out:
# [[ 210.8690033   210.98300171  210.79200745 ...,  210.69500732
#    210.69500732  210.69500732]
#  [ 211.22799683  210.8690033   211.15100098 ...,  210.69500732
#    210.69500732  210.69500732]
#  [ 210.77200317  211.          210.69500732 ...,  210.69500732
#    210.69500732  210.69500732]
#  ...,
#  [ 210.69500732  210.69500732  210.69500732 ...,  210.69500732
#    211.21099854  211.21099854]
#  [ 210.69500732  210.69500732  210.69500732 ...,  210.69500732
#    210.69500732  210.69500732]
#  [ 210.69500732  210.69500732  210.69500732 ...,  210.69500732
#    210.69500732  210.69500732]]
