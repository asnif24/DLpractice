# %%
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec


# %matplotlib inline

# %%
mnist = input_data.read_data_sets("MNIST_data/", one_hot = True)
x_train = mnist.train.images
y_train = mnist.train.labels
x_test = mnist.test.images
y_test = mnist.test.labels
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
x = np.arange(5)
y = x
# plt.figure(figsize=(60,1)) 
# plt.plot()

gg_pic = np.array([np.reshape(m,(28,28)) for m in x_train])
fig, ax = plt.subplots(nrows=3, ncols=3)
for i,row in enumerate(ax):
    for j,col in enumerate(row):
        ax[i][j].imshow(gg_pic[i*3+j], cmap='gray')
# plt.savefig('test734.png')

# %%
gg_pic = np.array([np.reshape(m,(28,28)) for m in x_train[0:20]])

fig = plt.figure(figsize=(10,2))

# gs1 = gridspec.GridSpec(4, 4)
# gs1.update(wspace=0, hspace=0)
# plt.subplot.title("MNIST")
# fig.title("MNIST")
for i in range(4):
    plt.subplot(2, 2, i+1)
    plt.imshow(gg_pic[i], cmap='gray')
    plt.axis('off')
# plt.show()
plt.subplots_adjust(wspace=0, hspace=0)
plt.savefig('test3.png')

for i in range(20):
    plt.subplot(2, 10, i+1)
    plt.imshow(gg_pic[i], cmap='gray')
#     plt.set_adjustable('box-forced')
    plt.axis('off')
    
# plt.show()
plt.subplots_adjust(wspace=0, hspace=0)
plt.savefig('test2.png', bbox_inches='tight', pad_inches = 0)
