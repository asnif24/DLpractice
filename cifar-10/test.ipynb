# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
def unpickle(file):
    import cPickle
    with open(file, 'rb') as fo:
        dict = cPickle.load(fo)
    return dict

# %%
path = "./data/cifar-10-batches-py/data_batch_1"
a = unpickle(path)

# %%
a.keys()
# Out:
# ['data', 'labels', 'batch_label', 'filenames']

# %%
a["data"]
# Out:
# array([[ 59,  43,  50, ..., 140,  84,  72],
#        [154, 126, 105, ..., 139, 142, 144],
#        [255, 253, 253, ...,  83,  83,  84],
#        ...,
#        [ 71,  60,  74, ...,  68,  69,  68],
#        [250, 254, 211, ..., 215, 255, 254],
#        [ 62,  61,  60, ..., 130, 130, 131]], dtype=uint8)

# %%
# plt.imshow(a["data"][0])
a["labels"]
# Out:
# [6,
#  9,
#  9,
#  4,
#  1,
#  1,
#  2,
#  7,
#  8,
#  3,
#  4,
#  7,
#  7,
#  2,
#  9,
#  9,
#  9,
#  3,
#  2,
#  6,
#  4,
#  3,
#  6,
#  6,
#  2,
#  6,
#  3,
#  5,
#  4,
#  0,
#  0,
#  9,
#  1,
#  3,
#  4,
#  0,
#  3,
#  7,
#  3,
#  3,
#  5,
#  2,
#  2,
#  7,
#  1,
#  1,
#  1,
#  2,
#  2,
#  0,
#  9,
#  5,
#  7,
#  9,
#  2,
#  2,
#  5,
#  2,
#  4,
#  3,
#  1,
#  1,
#  8,
#  2,
#  1,
#  1,
#  4,
#  9,
#  7,
#  8,
#  5,
#  9,
#  6,
#  7,
#  3,
#  1,
#  9,
#  0,
#  3,
#  1,
#  3,
#  5,
#  4,
#  5,
#  7,
#  7,
#  4,
#  7,
#  9,
#  4,
#  2,
#  3,
#  8,
#  0,
#  1,
#  6,
#  1,
#  1,
#  4,
#  1,
#  8,
#  3,
#  9,
#  6,
#  6,
#  1,
#  8,
#  5,
#  2,
#  9,
#  9,
#  8,
#  1,
#  7,
#  7,
#  0,
#  0,
#  6,
#  9,
#  1,
#  2,
#  2,
#  9,
#  2,
#  6,
#  6,
#  1,
#  9,
#  5,
#  0,
#  4,
#  7,
#  6,
#  7,
#  1,
#  8,
#  1,
#  1,
#  2,
#  8,
#  1,
#  3,
#  3,
#  6,
#  2,
#  4,
#  9,
#  9,
#  5,
#  4,
#  3,
#  6,
#  7,
#  4,
#  6,
#  8,
#  5,
#  5,
#  4,
#  3,
#  1,
#  8,
#  4,
#  7,
#  6,
#  0,
# ...

# %%
a
# Out:
# {'batch_label': 'training batch 1 of 5',
#  'data': array([[ 59,  43,  50, ..., 140,  84,  72],
#         [154, 126, 105, ..., 139, 142, 144],
#         [255, 253, 253, ...,  83,  83,  84],
#         ...,
#         [ 71,  60,  74, ...,  68,  69,  68],
#         [250, 254, 211, ..., 215, 255, 254],
#         [ 62,  61,  60, ..., 130, 130, 131]], dtype=uint8),
#  'filenames': ['leptodactylus_pentadactylus_s_000004.png',
#   'camion_s_000148.png',
#   'tipper_truck_s_001250.png',
#   'american_elk_s_001521.png',
#   'station_wagon_s_000293.png',
#   'coupe_s_001735.png',
#   'cassowary_s_001300.png',
#   'cow_pony_s_001168.png',
#   'sea_boat_s_001584.png',
#   'tabby_s_001355.png',
#   'muntjac_s_001000.png',
#   'arabian_s_001354.png',
#   'quarter_horse_s_000672.png',
#   'passerine_s_000343.png',
#   'camion_s_001895.png',
#   'trailer_truck_s_000335.png',
#   'dumper_s_000821.png',
#   'alley_cat_s_000200.png',
#   'accentor_s_000677.png',
#   'frog_s_001671.png',
# ...

# %%
pics = a["data"]
pics_reshape = np.reshape(pics[0], [32,32,3])
print pics_reshape
plt.imshow(pics_reshape)
# Out:
# [[[ 59  43  50]
#   [ 68  98 119]
#   [139 145 149]
#   ...,
#   [127 126 127]
#   [130 142 130]
#   [118 120 109]]
#
#  [[ 33  38  87]
#   [106 115 117]
#   [114 105 107]
#   ...,
#   [118 140 136]
#   [120 107  88]
#   [ 67  35  32]]
#
#  [[ 97 111 123]
#   [130 136 132]
#   [122 121 127]
#   ...,
#   [ 76 107 135]
#   [135 129 127]
#   [119 125 134]]
#
#  ...,
#  [[ 72  44  42]
#   [ 52  72  64]
#   [ 58  57  81]
#   ...,
#   [ 66  62  52]
#   [ 39  39  44]
#   [ 87 114  58]]
#
#  [[ 82  26  25]
#   [ 34  41  49]
#   [ 53  56  58]
#   ...,
#   [ 55  61  68]
#   [ 59  46  98]
#   [ 87   9   9]]
#
#  [[ 96  34  26]
#   [ 27  34  32]
#   [ 42  52  49]
#   ...,
#   [ 58  65  59]
#   [ 46  57 104]
#   [140  84  72]]]

# %%
pics[0]
# Out:
# array([ 59,  43,  50, ..., 140,  84,  72], dtype=uint8)

# %%
pic = pics[0].reshape((3,1024))
print pic
# Out:
# [[ 59  43  50 ..., 216 151 123]
#  [ 62  46  48 ..., 184 118  92]
#  [ 63  45  43 ..., 140  84  72]]

# %%
pic = pics[0].reshape((1024,3), order='F')
print pic
# Out:
# [[ 59  62  63]
#  [ 43  46  45]
#  [ 50  48  43]
#  ...,
#  [216 184 140]
#  [151 118  84]
#  [123  92  72]]

# %%
print pics[0].reshape([1024, 3], order='F')
# Out:
# [[ 59  62  63]
#  [ 43  46  45]
#  [ 50  48  43]
#  ...,
#  [216 184 140]
#  [151 118  84]
#  [123  92  72]]

# %%
q = pics[0].reshape((32,32,3), order='F')
print q
plt.imshow(q)
# Out:
# [[[ 59  62  63]
#   [ 16  20  20]
#   [ 25  24  21]
#   ...,
#   [208 170  96]
#   [180 139  96]
#   [177 144 116]]
#
#  [[ 43  46  45]
#   [  0   0   0]
#   [ 16   7   0]
#   ...,
#   [201 153  34]
#   [173 123  42]
#   [168 129  94]]
#
#  [[ 50  48  43]
#   [ 18   8   0]
#   [ 49  27   8]
#   ...,
#   [198 161  26]
#   [186 144  30]
#   [179 142  87]]
#
#  ...,
#  [[158 132 108]
#   [123  88  55]
#   [118  84  50]
#   ...,
#   [160 133  70]
#   [184 148  94]
#   [216 184 140]]
#
#  [[152 125 102]
#   [119  83  50]
#   [120  84  50]
#   ...,
#   [ 56  31   7]
#   [ 97  62  34]
#   [151 118  84]]
#
#  [[148 124 103]
#   [122  87  57]
#   [109  73  42]
#   ...,
#   [ 53  34  20]
#   [ 83  53  34]
#   [123  92  72]]]

# %%
pics[0]
# Out:
# array([ 59,  43,  50, ..., 140,  84,  72], dtype=uint8)

# %%
q = pics[0].reshape(3,1024).transpose().reshape(32,32,3)
print q.shape
plt.imshow(q)
# Out:
# (32, 32, 3)

# %%
z=[[1],[2],[3]]
x=[[4],[5],[6]]
c=[[7],[8],[9]]
v = np.concatenate([z,x,c])
print v
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]
#  [6]
#  [7]
#  [8]
#  [9]]

# %%
pics[0]
# Out:
# array([ 59,  43,  50, ..., 140,  84,  72], dtype=uint8)

# %%
p = np.dstack((i for i in pics[0].reshape(3,32,32))) 
print p.shape
plt.imshow(p)
# Out:
# (32, 32, 3)

# %%
print pics[0]
p0 = pics.reshape(3,-1)
print p0
p = np.dstack((i for i in pics.reshape(-1,3,1024))) 
print p.shape
print p
pp = p.reshape(-1,32,32,3)
# print pp
plt.imshow(pp[0])
# Out:
# [ 59  43  50 ..., 140  84  72]
# [[ 59  43  50 ..., 181 222 250]
#  [153 150 151 ..., 141 139 136]
#  [151 123  79 ..., 130 130 131]]
# (3, 1024, 10000)
# [[[ 59 154 255 ...,  71 250  62]
#   [ 43 126 253 ...,  60 254  61]
#   [ 50 105 253 ...,  74 211  60]
#   ...,
#   [216 143  78 ...,  80 214 167]
#   [151 143  79 ...,  83 255 167]
#   [123 143  80 ...,  84 255 167]]
#
#  [[ 62 177 255 ...,  77 255  55]
#   [ 46 137 253 ...,  69 253  55]
#   [ 48 104 253 ...,  83 224  55]
#   ...,
#   [184 133  85 ...,  73 212 198]
#   [118 134  85 ...,  75 255 198]
#   [ 92 133  86 ...,  77 254 198]]
#
#  [[ 63 187 255 ...,  44 255   7]
#   [ 45 136 253 ...,  35 254   7]
#   [ 43  95 253 ...,  56 220   6]
#   ...,
#   [140 139  83 ...,  68 215 130]
#   [ 84 142  83 ...,  69 255 130]
#   [ 72 144  84 ...,  68 254 131]]]

# %%
q = pics[0].reshape(3,32,32).transpose()
print q.shape
plt.imshow(q)
# Out:
# (32, 32, 3)

# %%
q = pics.reshape(-1,3,1024).transpose().reshape(-1,32,32,3)
print q.shape
plt.imshow(q[0])
# Out:
# (10000, 32, 32, 3)

# %%
from PIL import Image

# %%
img = Image.fromarray(pics[0].reshape(3,32,32), 'RGB')
plt.imshow(img)

# %%
p = np.dstack(pics[0].reshape(3,32,32))
print p.shape
plt.imshow(p)
# Out:
# (32, 32, 3)

# %%
ppp = np.array([np.dstack(i.reshape(3,32,32)) for i in pics])
print ppp.shape
plt.imshow(ppp[0])
# Out:
# (10000, 32, 32, 3)
